# %%
import pandas as pd 

df =pd.read_csv('industry.csv')
print(df)
# Out:
#                          Industry
# 0              Accounting/Finance
# 1    Advertising/Public Relations
# 2              Aerospace/Aviation
# 3   Arts/Entertainment/Publishing
# 4                      Automotive
# 5                Banking/Mortgage
# 6            Business Development
# 7            Business Opportunity
# 8         Clerical/Administrative
# 9         Construction/Facilities
# 10                 Consumer Goods
# 11               Customer Service
# 12             Education/Training
# 13               Energy/Utilities
# 14                    Engineering
# 15            Government/Military
# 16                          Green
# 17                     Healthcare
# 18             Hospitality/Travel
# 19                Human Resources
# 20       Installation/Maintenance
# 21                      Insurance
# 22                       Internet
# 23                Job Search Aids
# 24       Law Enforcement/Security
# 25                          Legal
# ...

# %%
print(df.head())
# Out:
#                         Industry
# 0             Accounting/Finance
# 1   Advertising/Public Relations
# 2             Aerospace/Aviation
# 3  Arts/Entertainment/Publishing
# 4                     Automotive

# %%
print(df.tail())
# Out:
#                     Industry
# 38             Skilled Labor
# 39                Technology
# 40        Telecommunications
# 41  Transportation/Logistics
# 42                     Other

# %%
data = {
    'Date':['2024-01-15', '2024-01-16', '2024-01-17', '2024-01-18', '2024-01-19'],
    'Product':['Laptop', 'Mouse', 'Laptop', 'Keyboard', 'Mouse'],
    'Category': ['Electronic', 'Accessories', 'Electronics', 'Accessories', 'Accessories' ],
    'Sales':[1200,25,1150,45,30],
    'Quantity':[1,2,1,3,2]
}

# %%
import pandas as pd 
df1=pd.DataFrame(data)
print(df1)
# Out:
#          Date   Product     Category  Sales  Quantity
# 0  2024-01-15    Laptop   Electronic   1200         1
# 1  2024-01-16     Mouse  Accessories     25         2
# 2  2024-01-17    Laptop  Electronics   1150         1
# 3  2024-01-18  Keyboard  Accessories     45         3
# 4  2024-01-19     Mouse  Accessories     30         2

# %%
print(df1.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      5 non-null      str
#  1   Product   5 non-null      str
#  2   Category  5 non-null      str
#  3   Sales     5 non-null      int64
#  4   Quantity  5 non-null      int64
# dtypes: int64(2), str(3)
# memory usage: 332.0 bytes
# None

# %%
print(df1.describe())
# Out:
#              Sales  Quantity
# count     5.000000   5.00000
# mean    490.000000   1.80000
# std     625.609703   0.83666
# min      25.000000   1.00000
# 25%      30.000000   1.00000
# 50%      45.000000   2.00000
# 75%    1150.000000   2.00000
# max    1200.000000   3.00000

# %%
import pandas as pd1
df2=pd1.read_csv("day.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 import pandas as pd1
# ----> 2 df2=pd1.read_csv("day.csv")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
print(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(df2)
#
# NameError: name 'df2' is not defined
