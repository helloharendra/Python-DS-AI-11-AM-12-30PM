# %%
print('hello')
# Out:
# hello

# %% [markdown]
# #python first heading

# %% [markdown]
# ##python second heading

# %% [markdown]
# print('hello')

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# # python basic

# %% [markdown]
# ## python

# %% [markdown]
# ### python

# %% [markdown]
# - this is my file

# %%
print('naya prayog')
# Out:
# naya prayog

# %%
name='naya prayog'
print(name)
print(name)
print(name)
# Out:
# naya prayog
# naya prayog
# naya prayog

# %%
name='naya prayog'
print(name*10)
# Out:
# naya prayognaya prayognaya prayognaya prayognaya prayognaya prayognaya prayognaya prayognaya prayognaya prayog

# %%
print('hello\n'*10)
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
for i in range(10):
    print('naya prayog')
# Out:
# naya prayog
# naya prayog
# naya prayog
# naya prayog
# naya prayog
# naya prayog
# naya prayog
# naya prayog
# naya prayog
# naya prayog

# %%
print(10+20)
# Out:
# 30

# %%
a=10
b=40
c=a+b
print(c)
# Out:
# 50

# %%
a=input('Enter your name:')
print(a)
# Out:
# naya prayog

# %%
a=int(input('Enter a number'))
b=int(input('Enter another number'))
c=a+b
print(c)
# Out:
# 94

# %%
a=(input('enter a number'))
b=(input('enter another number'))
c=a+b
print(c)
