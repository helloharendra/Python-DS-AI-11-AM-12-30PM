# %% [markdown]
# # First python program
# - first
# - second
# - third
#
# today we will learn about basic python programming.

# %%
print('hello world')
# Out:
# hello world

# %%
print(10+20)
# Out:
# 30

# %%
a=10
b=40
c=a+b
print('Sum of a and b is: ',c)
# Out:
# Sum of a and b is:  50

# %%
a=int(input('Enter value of a'))
b=int(input('Enter value of b'))
c=a+b
print(c)
# Out:
# 75
