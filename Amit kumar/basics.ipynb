# %%
a=10

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
type(a)
# Out:
# int

# %%
a=float(a)

# %%
type(a)
# Out:
# float

# %%
print(a)
# Out:
# 10.0

# %%
a='100'

# %%
type(a)
# Out:
# str

# %%
a=int(a)

# %%
type(a)
# Out:
# int

# %%
age=16
if age>18:
    print('eligible')
else:
    print('not eligible')
# Out:
# not eligible

# %%
light='greed'
if light=='red':
    print('Stop')
else:
    print('Go')
# Out:
# Go

# %%
light=input('Enter signal color like red or green')
if light=='red':
    print('Stop')
else:
    print('Go')
# Out:
# Go

# %%
speed=120

if speed>=80:
    print('challan of 500')
else:
    print('no challan')
# Out:
# challan of 500
