# %% [markdown]
# # my first heading program
# ## my first heading program
# ### my first heading program

# %%
a = 15
b = 20
c = a+b
print('sum of an and b is ',c)
# Out:
# sum of an and b is  35

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# - first day1
# - second day2
# - third day3
