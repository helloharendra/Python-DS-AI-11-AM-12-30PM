# %% [markdown]
# # Control flow in Python

# %%
# top to botom approch

print('hello')
print('roshan')
print('prashant')
print('netika')
print('vikash')
print('Akash')
# Out:
# hello
# roshan
# prashant
# netika
# vikash
# Akash

# %%
age=18

if age>=18:
    print('eligible for voting')
# Out:
# eligible for voting

# %%
age=20

if age==18:
    print('eligible for voting')
else:
    print('not eligible')
# Out:
# not eligible

# %%
singal='red'

if singal=='green':
    print('Go')
else:
    print('Stop')
# Out:
# Stop

# %%
singal='green'

if singal=='green':
    print('Go')
elif singal=='yellow':
    print('Caution')
else:
    print('Stop')
# Out:
# Go

# %%
singal=input('Enter the colour of light')

if singal=='green':
    print('Go')
elif singal=='yellow':
    print('Caution')
elif singal=='red':
    print('Stop')
else:
    print('Invalid signal color please enter valid color')
# Out:
# Invalid signal color please enter valid color

# %%
mark=int(input('Enter your mark out of 100'))

if mark>=90:
    print('Grade A+')
elif mark>=80:
    print('Grade A')
elif mark>=75:
    print('Grade B+')
elif mark>=60:
    print('Grade B')
elif mark>=50:
    print('Grade C')
elif mark>=40:
    print('Grade D')
else:
    print('You are failed try again...')
# Out:
# Grade A+

# %%
age=int(input('Enter your age'))
citizen=False
if age>=18:

    if citizen:
        print('eligible for vote')
    else:
        print(' not eligible for vote 1111')   
else:
    print(' not eligible for vote 222222')
# Out:
#  not eligible for vote 1111

# %%
age=int(input('Enter your age'))
citizen=True

if age>=18:
    if citizen:
        print('eligible for vote')
    else:
        print('condition 2 is fals')
else:
    print(' not eligible for vote 222222')
# Out:
# condition 1 is true
# eligible for vote

# %%
age=int(input('Enter your age'))
citizenship=input('Enter you country')

if age>=18:
    print('condition 1 is true')
    if citizenship=='india':
        print('condition 2 is true')
        print('eligible for vote')
    else:
        print('condition 1 is true but condition 2 is false')

        print(' not eligible for vote 1111')   
else:
    print(' not eligible for vote 222222')
# Out:
#  not eligible for vote 222222

# %%
age=int(input('Enter your age'))
citizenship=input('Enter you country')


if (age>=18 and citizenship=='india'):
    print(' eligible for vote')  
   
else:
    print(' not eligible for vote 222222')
# Out:
#  not eligible for vote 222222
