# %%
mylist=[10,20,30,40,50,60]
for i, val in enumerate(mylist):
    if val==100:
        print('found')
print('not found')
# Out:
# not found

# %% [markdown]
# # Static vs Dynamic list

# %% [markdown]
# ### Static

# %%
l1=[10,20,30,40,50]

print(len(l1))
# Out:
# 4

# %% [markdown]
# ### Dynamic

# %%
l2=[]


l2.append(10)

# %%
print(l2)
# Out:
# [10]

# %%
l2.append(20)

# %%
print(l2)
# Out:
# [10, 20]
