# %% [markdown]
# # Bitwise Operators

# %%
a='india' 
b=18
c='ataruliya'

if(a=='india' and b>=18 and c=='pahiya'):
    print('eligible') 
else:
    print('not eligible')
# Out:
# not eligible

# %%
a='rewr' 
b=17

if(a=='india' or b>=18 ):
    print('eligible') 
else:
    print('not eligible')
# Out:
# not eligible

# %%
a=(input('enter first name'))
b=input('enter second name')

c=int(a)
d=int(b)

f=(c+d)
print(f)
# Out:
# 30

# %%
a=4
b=3
c=a**b
print(c+b)
# Out:
# 67
