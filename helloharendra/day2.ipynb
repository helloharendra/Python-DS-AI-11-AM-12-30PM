# %%
#varriables in  python ---  > this is single

# %%
"""what is varriable
 varriable is a containe which is 
used to store data

data type
dfs
sdfsd

ScribdDocumentf
setf
(diff-diff data we can store here)"""
# Out:
# 'what is varriable\n varriable is a containe which is \nused to store data\n\ndata type\ndfs\nsdfsd\n\nScribdDocumentf\nsetf\n(diff-diff data we can store here)'

# %%
address='''Naya prayog
 technology Atrauliya
  
   sfs
    sfs
      azamgarh'''

# %%
print(address)
# Out:
# Naya prayog
#  technology Atrauliya
#
#    sfs
#     sfs
#       azamgarh

# %%
# data type in python

# %%
a=10
b=1.5
c=True
print(type(a))
print(type(address))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
numbers= [1,2,3,4,5,9,7,4]
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 9, 7, 4]

# %%
print(type(numbers))
# Out:
# <class 'list'>

# %%
print(numbers[4])
# Out:
# 5

# %%
print(numbers[4])
# Out:
# 5

# %%
print(numbers[8-1])
# Out:
# 4

# %%
print()
# Out:
# <method-wrapper '__len__' of list object at 0x112593900>

# %%
# touple in python

# %%
data=(1,2,3)
print(data)
# Out:
# (1, 2, 3)

# %%
# set in python

# %%
mydata={4,5,6,4,4,4,8}
print(mydata)
# Out:
# {8, 4, 5, 6}

# %%
# Disctonary in python

# %%
students={
    "name":"vikash",
    "age":"19",
}

print(students)
# Out:
# {'name': 'vikash', 'age': '19'}
