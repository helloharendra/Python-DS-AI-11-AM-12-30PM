# %%
print('day 3')
# Out:
# day 3

# %%
name ="Naya prayog Academy"

# %%
print(name)
# Out:
# Naya prayog Academy

# %%
new_name=input('Enter your name')
age=input('Enter you age')
print("Name: "+new_name)
print('age: '+age)
# Out:
# Name: prashant
# age: 17

# %%
a=int(input('Enter first number'))
b=int(input('Enter your second number'))
c=(a+b)
print(f"Sum of two number :{c}")
# Out:
# Sum of two number :100

# %%
print(type(a))
# Out:
# <class 'str'>
