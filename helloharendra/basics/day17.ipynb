# %%
def myFunction():
    return print('hello my first function')

# %%
myFunction()
# Out:
# hello my first function

# %%
def name():
    print('naya prayog')

# %%
print(name())
# Out:
# naya prayog
# None

# %%
def sum():
    a=10
    b=20
    return print(a+b)

# %%
sum()
# Out:
# 30

# %%
def sum1(a,b):
    return print(a+b)

# %%
sum1(10,20)
# Out:
# 30

# %%
sum1(50,60)
# Out:
# 110

# %%
sum1(41,45)
# Out:
# 86

# %% [markdown]
# # Generators
# - A generator is a special type of function that:
# - Returns values one at a time
# - Uses the keyword yield instead of return
# - Does not store all values in memory

# %%
def printmyname():
    print('hello')

# %%
printmyname()
# Out:
# hello
