# %%
a=10
b=20
print(a+b)
print(b-a)
print(a*b)
print(b/a)
# Out:
# 30
# 10
# 200
# 2.0

# %%
print(a,b)
# Out:
# 10 20

# %%
c=50
d=70

# %%
print(a,b,c,d)
# Out:
# 10 20 50 70

# %%
a=b

# %%
print(a,b,c,d)
# Out:
# 20 20 50 70

# %%
a==b
# Out:
# True

# %%
a=10

# %%
print(a,b,c,d)
# Out:
# 10 20 50 70

# %%
a==b
# Out:
# False

# %%
a>b
# Out:
# False

# %%
b>a
# Out:
# True

# %%
a<b
# Out:
# True

# %%
print(a,b,c,d)
# Out:
# 20 20 30 40

# %%
a=b

# %%
print(a,b,c,d)
# Out:
# 20 20 30 40

# %%
a=10
b=20
c=30
d=40
e=50
print(a,b,c,d,e)
# Out:
# 10 20 30 40 50

# %%
e=a

# %%
print(a,b,c,d,e)
# Out:
# 10 20 30 40 10

# %%
a==b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<=e
# Out:
# True

# %%
a>=e
# Out:
# True

# %%
a!=e
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
print(a,b,c,d,e)
# Out:
# 10 20 30 40 10

# %%
a==e
# Out:
# True

# %%
a!=e
# Out:
# False

# %%
a==e or a>b
# Out:
# True

# %%
print(a,b,c,d,e)
# Out:
# 10 20 30 40 10

# %%
a==b or b > c or a==e
# Out:
# True

# %%
a==b and b < c and a==e
# Out:
# False

# %%
a==e and b<c and c<d
# Out:
# True

# %%
type(a)
# Out:
# int

# %%
num = input('enter first num')

# %%
print(num)
# Out:
# 50

# %%
type(num)
# Out:
# str

# %%
num1=(input('fist num'))
num2=input('second number')

num3=float(num1)
num4=float(num2)
print(num3+num4)
# Out:
# 92.0

# %%
type(num1)
type(num2)
# Out:
# str
