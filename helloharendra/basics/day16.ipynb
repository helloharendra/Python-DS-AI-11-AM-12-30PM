# %% [markdown]
# # Exception Handling in Python
#
# Exception handling is used to handle runtime errors so your program doesn’t crash unexpectedly.
#
# ### Why we use it
# - Prevents program from crashing
# - Handles errors gracefully
# - Improves user experience
# - Helps debug issues easily

# %%
try:
    num = int(input("Enter number: "))
    print(10 / num)
except ZeroDivisionError:
    print("Cannot divide by zero")
except ValueError:
    print("Invalid input please enter valid number")

except Exception as e:
    print('Exception',e)

finally:
    print('Task Done')
# Out:
# 0.43478260869565216
# Task Done

# %%
x = 3
assert x > 0, "x must be positive"

# %%
try:
    open('text.txt','r')

except Exception as e:
    print("Error ",e)
# Out:
# Error  [Errno 2] No such file or directory: 'text.txt'

# %%
with open("text.txt", "r") as f:
    data = f.read()

# %%
print(data)
# Out:
# hello
# naya prayog

# %%
def count_up(n):
    for i in range(n):
        yield i
for num in count_up(5):
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
count_up(12)
# Out:
# <generator object count_up at 0x107fab3e0>

# %% [markdown]
# # Recursion
#
# - A function call itself

# %%
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n - 1)

print(factorial(10))
# Out:
# 3628800

# %%
for i in range(5):
    print("*")
# Out:
# *
# *
# *
# *
# *

# %%
print(factorial(5))
# Out:
# 120

# %%
print(factorial(8))
# Out:
# 40320
