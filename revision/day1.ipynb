# %%
print('hello')
# Out:
# hello

# %% [markdown]
# # addition

# %%
a=int(input('enter a number:'))
b=int(input('enter another number:'))
sum=a+b
print(sum)
# Out:
# 80

# %%
subs=b-a
print(subs)
# Out:
# 40

# %%
mul=a*b
print(mul)
# Out:
# 1200

# %%
div=b/a
print(div)
# Out:
# 3.0
