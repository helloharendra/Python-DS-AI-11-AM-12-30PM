# %% [markdown]
# ## Exception Handeling ##

# %%
print("Roshan")
# Out:
# Roshan

# %%
try:
    a=int(input("enter your first number"))
    b=int(input("enter your second number"))
    c=a/b
    print(c)
except ZeroDivisionError:
    print("error can not divided by zero")
except ValueError:
    print("enter valid input")
finally :
    print("excecution completed")
# Out:
# 1.0
# excecution completed

# %% [markdown]
# ## How to create function

# %%
def myfunction(a,b):
    c=a+b
    d=a-b
    e=a*b
    print(c,d,e)

# %%
myfunction(20,10)
# Out:
# 30 10 200

# %%
def ifelsefunction1(name,age):

    if name=="Roshan" and age==20:
        print("Right person")
    else:
        print("wrong person")

# %%
def ifelsefunction(name):

    if name=="Roshan":
        print("Right person")
    else:
        print("wrong person")

# %%
ifelsefunction("Roshan")
# Out:
# Right person

# %%
ifelsefunction1("Ram",20)
# Out:
# wrong person

# %%
def matchcasefunction(x):
    match x:
        case 0:
            print("this is xero ")
        case x if (x%2==0):
            print("this is even number")
        case x if(x%1==0):
            print("this is odd number")

# %%
matchcasefunction(9)
# Out:
# this is odd number

# %%
order=int(input("enter your order in range 1-4"))

# %%
order=int(input("enter your order in range 1-4"))
def restaurantfunction(order):
   curd=10
   samosa=15
   saahi_paneer=10
   tandoori_chicken=5
   match order:
      case 1:
        print('your order: curd')
      case 2:
        print('your order: samosa')
      case 3:
        print('your order: saahi paneer')
      case 4:
        print('your order: tandoori chicken')
      case _:
        print('invalid order')

# %%
restaurantfunction(1)
# Out:
# your order: curd

# %% [markdown]
# ## examples of exception

# %%
try:
      order=int(input("give your order please 1-4"))
      curd=10
      samosa=15
      saahi_paneer=10
      tandoori_chicken=5
      match order:
         case 1:
            print('your order: curd')
            curd-=1
            print(curd)
         case 2:
            print('your order: samosa')
            samosa-=1
            print(samosa)
         case 3:
            print('your order: saahi paneer')
            saahi_paneer-=1
            print(saahi_paneer)
         case 4:
            print('your order: tandoori chicken')
            tandoori_chicken-=1
            print(tandoori_chicken)
         case _:
            print('invalid order')
except ValueError:
      print("enter valid input")
finally          :
      print("excecution completed")
# Out:
# your order: samosa
# 14
# excution completed

# %% [markdown]
# ### exception handelling in if else

# %%
try:
    cardnumber=(input('enter your card number'))
    if len(cardnumber)==16:
        print('valid card number')
        cvv=(input('enter your cvv'))
        if len(cvv)==3:
            print('valid cvv')
            otp=(input('enter your otp'))
            if len(otp)==4:
               print('valid otp')
               card_pin=(input('enter your card pin'))
               if len(card_pin)==4:
                 print('valid card_pin transcation successful')
               else:
                  print('wrong pin please enter valid pin')
            else:
                print('wrong otp please enter valid otp')
        else:
            print('wrong cvv please enter valid cvv')
    else:
        print('wrong card number please valid card number')
except ValueError:
    print("please enter valid input")
finally:
     print("excecution completed")
# Out:
# wrong card number please valid card number
# excecution completed

# %%
def function3(paymentgateway):
    cardnumber=(input('enter your card number'))
    if len(cardnumber)==16:
       print('valid card number')
       cvv=(input('enter your cvv'))
       if len(cvv)==3:
          print('valid cvv')
          otp=(input('enter your otp'))
          if len(otp)==4:
             print('valid otp')
             card_pin=(input('enter your card pin'))
             if  len(card_pin)==4:
                 print('valid card_pin transcation successful')
             else:
                 print('wrong pin please enter valid pin')
          else:
              print('wrong otp please enter valid otp')
       else:
           print('wrong cvv please enter valid cvv')
    else:
        print('wrong card number please valid card number')

# %%
function3(1)
# Out:
# valid card number
# valid cvv
# valid otp
# valid card_pin transcation successful

# %%
def sum():
    a=10
    b=20
    return(a+b)

# %%
sum()
# Out:
# 30

# %%
def sum1(a,b):
    return(a+b)

# %%
sum1(10,30)
# Out:
# 40
