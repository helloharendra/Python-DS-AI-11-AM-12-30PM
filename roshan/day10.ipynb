# %%
print('hello roshan')
# Out:
# hello roshan

# %% [markdown]
# # ternary operaters
# - short form of if-else
# - The ternary operator in python is a one-line shortcut for writing simple
# if -else conditions

# %%
age=18

# %%
result=print('can vote')if age>=18 else print("can't vote")
# Out:
# can vote

# %%
result= 'adult' if age>=18 else 'minor'

# %%
print(result)
# Out:
# adult

# %% [markdown]
# # loops
# - for loop

# %%
for b in range(5):
    print('ram')
# Out:
# ram
# ram
# ram
# ram
# ram

# %%
for b in range(5):
    print(f'{b}radhe')
# Out:
# 0radhe
# 1radhe
# 2radhe
# 3radhe
# 4radhe

# %%
for i in range(10):
    print('radhe')
# Out:
# radhe
# radhe
# radhe
# radhe
# radhe
# radhe
# radhe
# radhe
# radhe
# radhe

# %%
for i in range(20):
    print('Roshan')
# Out:
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
# Roshan
