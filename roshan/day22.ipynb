# %%
arr=[20,30,40,50]
for i,val in enumerate(arr):
    if val==40:
        print("found")
# Out:
# found

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## static vs dynamic

# %% [markdown]
# #### static

# %%
l2=[20,30,40,50]

# %%
print(l2)
# Out:
# [20, 30, 40, 50]

# %% [markdown]
# #### dynamic

# %%
l3=[]

# %%
l3.append(10)

# %%
print(l3)
# Out:
# [10]
