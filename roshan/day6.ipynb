# %% [markdown]
# ## operators

# %%
a='australia' 
b=18
c='ataruliya'

if(a=='india' and b>=18 and c=='kanailaa'):
    print('eligible') 
else:
    print('not eligible')

# %%
print('hello world')

# %%
a=(input('enter first name'))
b=input('enter second name')

c=int(a)
d=int(b)

f=(c+d)
print(f)
# Out:
# 50

# %%
y=int(input('enter your number'))
z=int(input('enter your number'))
x=(y**z)
print(x)
# Out:
# 3125
