# %% [markdown]
# ## Natural number

# %%
n=10
total=0
for i in range(1,n+1):
    total+=i
print(total)
# Out:
# 55

# %%
n=int(input("enter your number"))
total=0
for i in range(1,n+1):
    total+=i
print(total)
# Out:
# 1275

# %% [markdown]
# ## Searching

# %%
l1=[20,30,40,50]
if 20 in l1:
    print("20 is found")
else:
    print("element not found")
# Out:
# 20 is found
