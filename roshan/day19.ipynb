# %% [markdown]
# # DSA Introduction to data structure @ algorithms
# - data structure are ways to store and orgnize data so that it can be used efficiently. Algorithms are step
# -by -step procedures to solve a problem.
# ### Time complexity and Space complexity
# #### Time complexity measures how fast an algorithm
# -

# %%
print("hello")
# Out:
# hello

# %%
l1=[20,30,40,50]
for i in range(len(l1)):
    print(l1[i])
# Out:
# 20
# 30
# 40
# 50

# %%
l2=[20,30,40,50]
for i in l2:
    print(i)
# Out:
# 20
# 30
# 40
# 50

# %%
l2.append(60)

# %%
print(l2)
# Out:
# [20, 30, 40, 50, 60]

# %%
print(len(l2))
# Out:
# 5

# %%
l2.insert(2,80)

# %%
print(l2)
# Out:
# [20, 30, 80, 40, 50, 60]

# %%
l2.remove(40)

# %%
print(l2)
# Out:
# [20, 30, 80, 50, 60]

# %%
l2.pop(1)
# Out:
# 30

# %%
print(l2)
# Out:
# [20, 80, 50, 60]
