# %%
import pandas as pd
df=pd.read_csv('industry.csv')
print(df)
# Out:
#                          Industry
# 0              Accounting/Finance
# 1    Advertising/Public Relations
# 2              Aerospace/Aviation
# 3   Arts/Entertainment/Publishing
# 4                      Automotive
# 5                Banking/Mortgage
# 6            Business Development
# 7            Business Opportunity
# 8         Clerical/Administrative
# 9         Construction/Facilities
# 10                 Consumer Goods
# 11               Customer Service
# 12             Education/Training
# 13               Energy/Utilities
# 14                    Engineering
# 15            Government/Military
# 16                          Green
# 17                     Healthcare
# 18             Hospitality/Travel
# 19                Human Resources
# 20       Installation/Maintenance
# 21                      Insurance
# 22                       Internet
# 23                Job Search Aids
# 24       Law Enforcement/Security
# 25                          Legal
# ...

# %%
print(df.head())
# Out:
#                         Industry
# 0             Accounting/Finance
# 1   Advertising/Public Relations
# 2             Aerospace/Aviation
# 3  Arts/Entertainment/Publishing
# 4                     Automotive

# %%
print(df.tail())
# Out:
#                     Industry
# 38             Skilled Labor
# 39                Technology
# 40        Telecommunications
# 41  Transportation/Logistics
# 42                     Other

# %%
print(df.describe())
# Out:
#                   Industry
# count                   43
# unique                  43
# top     Accounting/Finance
# freq                     1

# %%
data = {
    'date':['2024-01-15','2024-01-16','2024-01-18','2024-01-19','2024-02-25'],
    'product':['laptop','mouse','laptop','keyboard','mouse'],
    'catergory':['electronic','accesories','electronics','accessories','accessories'],
    'sales':[1200,25,1150,45,30],
    'Quantity':[1,2,1,3,2]
}

# %%
df1 = pd.DataFrame(data)

# %%
print(df1)
# Out:
#          date   product    catergory  sales  Quantity
# 0  2024-01-15    laptop   electronic   1200         1
# 1  2024-01-16     mouse   accesories     25         2
# 2  2024-01-18    laptop  electronics   1150         1
# 3  2024-01-19  keyboard  accessories     45         3
# 4  2024-02-25     mouse  accessories     30         2

# %%
print(df1.describe())
# Out:
#              sales  Quantity
# count     5.000000   5.00000
# mean    490.000000   1.80000
# std     625.609703   0.83666
# min      25.000000   1.00000
# 25%      30.000000   1.00000
# 50%      45.000000   2.00000
# 75%    1150.000000   2.00000
# max    1200.000000   3.00000
