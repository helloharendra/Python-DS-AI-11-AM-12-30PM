# %% [markdown]
# ## imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print("="*60)
print("1.series(1D labeled array)")
print("="*60)
# Out:
# ...
# 1.series(1D labeled array)
# ...

# %%
s1 = pd.Series([10,20,30,40], index = ["a","b","c","d"])
print(f"list of series:\n",s1)
# Out:
# list of series:
#  a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s21 = pd.Series(['Roshan','Umesh','Mukesh','Mankram'],index=[1,2,3,4])
print(s21)
# Out:
# 1     Roshan
# 2      Umesh
# 3     Mukesh
# 4    Mankram
# dtype: str

# %%
s2 = pd.Series({'math':85, 'english':98, 'science':45, 'hindi':65})
print(f"series of dictionary\n",s2)
# Out:
# series of dictionary
#  math       85
# english    98
# science    45
# hindi      65
# dtype: int64

# %%
data = {
    'name':['Roshan','Vikash','Prashant','Vijay'],
    'age':[22,23,19,20],
    'city':['Atrauliya','Deoria','Azamgarh','Madiyapar'],
    'score':[34,43,56,43,]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        name  age       city  score
# 0    Roshan   22  Atrauliya     34
# 1    Vikash   23     Deoria     43
# 2  Prashant   19   Azamgarh     56
# 3     Vijay   20  Madiyapar     43

# %%
df2 = pd.DataFrame([(2,'x'), (3,'y')], columns=['id', 'names'])
print(df2)
# Out:
#    id names
# 0   2     x
# 1   3     y

# %%
df3 = pd.DataFrame([(2,'Roshan'), (3,'Pradeep')], columns=['id','Names'])
print(df3)
# Out:
#    id    Names
# 0   2   Roshan
# 1   3  Pradeep

# %%
df.to_csv('student.csv', index=False)
print()

# %%
df.to_excel('student.xlsx', index=False)
print()

# %%
import sys
!"{sys.executable}" -m pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print(df.head(2))
# Out:
#      name  age       city  score
# 0  Roshan   22  Atrauliya     34
# 1  Vikash   23     Deoria     43

# %%
print(df.tail(2))
# Out:
#        name  age       city  score
# 2  Prashant   19   Azamgarh     56
# 3     Vijay   20  Madiyapar     43

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      str
#  1   age     4 non-null      int64
#  2   city    4 non-null      str
#  3   score   4 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 260.0 bytes
# None

# %%
print(df.describe())
# Out:
#              age      score
# count   4.000000   4.000000
# mean   21.000000  44.000000
# std     1.825742   9.055385
# min    19.000000  34.000000
# 25%    19.750000  40.750000
# 50%    21.000000  43.000000
# 75%    22.250000  46.250000
# max    23.000000  56.000000

# %%
print(df.shape)
# Out:
# (4, 4)

# %%
print(df.columns)
# Out:
# Index(['name', 'age', 'city', 'score'], dtype='str')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
print(df.loc[1])
# Out:
# name     Vikash
# age          23
# city     Deoria
# score        43
# Name: 1, dtype: object

# %%
print(df.iloc[3])
# Out:
# name         Vijay
# age             20
# city     Madiyapar
# score           43
# Name: 3, dtype: object

# %%
print(df[0:2])
# Out:
#      name  age       city  score
# 0  Roshan   22  Atrauliya     34
# 1  Vikash   23     Deoria     43

# %%
print(df[['name','city','score']])
# Out:
#        name       city  score
# 0    Roshan  Atrauliya     34
# 1    Vikash     Deoria     43
# 2  Prashant   Azamgarh     56
# 3     Vijay  Madiyapar     43

# %%
print(df.iloc[1])
# Out:
# name     Vikash
# age          23
# city     Deoria
# score        43
# Name: 1, dtype: object

# %%
print(df[1:3])
# Out:
#        name  age      city  score
# 1    Vikash   23    Deoria     43
# 2  Prashant   19  Azamgarh     56

# %%
print(df[df['score']>50])
# Out:
#        name  age      city  score
# 2  Prashant   19  Azamgarh     56

# %%
df_nan1 = pd.DataFrame({
    'a':[1,np.nan,3,4],
    'b':[34,43,np.nan,23],
    'c':[23,1,4,np.nan]
})

# %%
print(df_nan1)
# Out:
#      a     b     c
# 0  1.0  34.0  23.0
# 1  NaN  43.0   1.0
# 2  3.0   NaN   4.0
# 3  4.0  23.0   NaN

# %%
print(df_nan1.isnull().any())
# Out:
# a    True
# b    True
# c    True
# dtype: bool

# %%
df_clean = (df_nan1.dropna())

# %%
print(df_clean)
# Out:
#      a     b     c
# 0  1.0  34.0  23.0

# %%
df_fill = df_nan1.fillna(0)

# %%
print(df_fill)
# Out:
#      a     b     c
# 0  1.0  34.0  23.0
# 1  0.0  43.0   1.0
# 2  3.0   0.0   4.0
# 3  4.0  23.0   0.0

# %%
print(df)
# Out:
#        name  age       city  score
# 0    Roshan   22  Atrauliya     34
# 1    Vikash   23     Deoria     43
# 2  Prashant   19   Azamgarh     56
# 3     Vijay   20  Madiyapar     43

# %%
df['bonus'] = df['score'] * 0.2

# %%
print(df)
# Out:
#        name  age       city  score  bonus
# 0    Roshan   22  Atrauliya     34    6.8
# 1    Vikash   23     Deoria     43    8.6
# 2  Prashant   19   Azamgarh     56   11.2
# 3     Vijay   20  Madiyapar     43    8.6

# %%
df['score_squred'] = df['score'].apply(lambda x:x**2)

# %%
df['score_squred']
# Out:
# 0    1156
# 1    1849
# 2    3136
# 3    1849
# Name: score_squred, dtype: int64

# %%
print(df)
# Out:
#        name  age       city  score  bonus  score_squred
# 0    Roshan   22  Atrauliya     34    6.8          1156
# 1    Vikash   23     Deoria     43    8.6          1849
# 2  Prashant   19   Azamgarh     56   11.2          3136
# 3     Vijay   20  Madiyapar     43    8.6          1849

# %%
df['score_add'] = df['score']+[10,20,30,40]

# %%
print(df)
# Out:
#        name  age       city  score  bonus  score_squred  score_add
# 0    Roshan   22  Atrauliya     34    6.8          1156         44
# 1    Vikash   23     Deoria     43    8.6          1849         63
# 2  Prashant   19   Azamgarh     56   11.2          3136         86
# 3     Vijay   20  Madiyapar     43    8.6          1849         83

# %%
df1 = pd.DataFrame({
    'ids':[101,102,103,104],
    'Name':['Ravi','Syam','Annu','Vinay'],
    'email_id':['ravi@gmail.com','shyam@gmail.com','aanu@gmail.com','vinay@gmail.com'],
    'designation':['Marketing','Sales','HR','HR'],
    'salary':[20000,25000,30000,24000]
})

# %%
print(df1)
# Out:
#    ids   Name         email_id designation  salary
# 0  101   Ravi   ravi@gmail.com   Marketing   20000
# 1  102   Syam  shyam@gmail.com       Sales   25000
# 2  103   Annu   aanu@gmail.com          HR   30000
# 3  104  Vinay  vinay@gmail.com          HR   24000

# %%
df1['bonus'] = df1['salary']+[2000,1250,3000,1200]

# %%
print(df1)
# Out:
#    ids   Name         email_id designation  salary  bonus
# 0  101   Ravi   ravi@gmail.com   Marketing   20000  22000
# 1  102   Syam  shyam@gmail.com       Sales   25000  26250
# 2  103   Annu   aanu@gmail.com          HR   30000  33000
# 3  104  Vinay  vinay@gmail.com          HR   24000  25200

# %%
print(df1.iloc[0,2])
# Out:
# ravi@gmail.com

# %%
dff = {
    'name':['Roshan','ravi','rahul'],
    'age':[23,22,21]
}

# %%
dfa = pd.DataFrame(dff,index=[101,102,103])

# %%
print(dfa)
# Out:
#        name  age
# 101  Roshan   23
# 102    ravi   22
# 103   rahul   21

# %%
print(dfa.iloc[1])
# Out:
# name    ravi
# age       22
# Name: 102, dtype: object

# %%
employee = {
    'Name':['Ram','Suresh','Ramesh','Rajesh'],
    'Age' :[22,25,30,25],
    'designation':['HR','Marketing','Sales','HR'],
    'Salary':[28000,22000,26000,25000],
}

# %%
employee_data = pd.DataFrame(employee)

# %%
print(employee_data)
# Out:
#      Name  Age designation  Salary
# 0     Ram   22          HR   28000
# 1  Suresh   25   Marketing   22000
# 2  Ramesh   30       Sales   26000
# 3  Rajesh   25          HR   25000

# %%
employee_data['increment_percentage'] = [8,10,12,5]

# %%
employee_data['increment'] = employee_data['Salary']*[8,10,12,5]/100

# %%
print(employee_data)
# Out:
#      Name  Age designation  Salary  increment_percentage  increment
# 0     Ram   22          HR   28000                     8     2240.0
# 1  Suresh   25   Marketing   22000                    10     2200.0
# 2  Ramesh   30       Sales   26000                    12     3120.0
# 3  Rajesh   25          HR   25000                     5     1250.0

# %%
employee_data['Total salary'] = employee_data['Salary']+ employee_data['increment']

# %%
print(employee_data)
# Out:
#      Name  Age designation  Salary  increment_percentage  increment  \
# 0     Ram   22          HR   28000                     8     2240.0
# 1  Suresh   25   Marketing   22000                    10     2200.0
# 2  Ramesh   30       Sales   26000                    12     3120.0
# 3  Rajesh   25          HR   25000                     5     1250.0
#
#    Total salary
# 0       30240.0
# 1       24200.0
# 2       29120.0
# 3       26250.0

# %%
print(employee_data.iloc[0,2])
# Out:
# HR

# %%
employee_data['Age_next_year'] = employee_data['Age']+1
print(employee_data[['Age','Age_next_year']])
# Out:
#    Age  Age_next_year
# 0   22             23
# 1   25             26
# 2   30             31
# 3   25             26

# %%
grouped = employee_data.groupby('designation')['Salary'].mean()

# %%
print(f"mean score by city",grouped)
# Out:
# mean score by city designation
# HR           26500.0
# Marketing    22000.0
# Sales        26000.0
# Name: Salary, dtype: float64

# %%
student_data = {
    'Name':['Roshan','Vikash','Akash','Ravi'],
    'Classes':[10,12,9,10],
    'adress':['atrauliya','atrauliya','madiyapar','lucknow'],
    'Marks':[75,65,45,58]
}

# %%
student1 = pd.DataFrame(student_data)

# %%
print(student1)
# Out:
#      Name  Classes     adress  Marks
# 0  Roshan       10  atrauliya     75
# 1  Vikash       12  atrauliya     65
# 2   Akash        9  madiyapar     45
# 3    Ravi       10    lucknow     58

# %%
grouped1 = student1.groupby('Classes')['Marks'].mean()

# %%
print(grouped1)
# Out:
# Classes
# 9     45.0
# 10    66.5
# 12    65.0
# Name: Marks, dtype: float64

# %%
agg_student = student1.groupby('adress').agg({
    'Marks':['min','mean','max'],
})

# %%
print(agg_student)
# Out:
#           Marks
#             min  mean max
# adress
# atrauliya    65  70.0  75
# lucknow      58  58.0  58
# madiyapar    45  45.0  45

# %%
grouped11 = student1.groupby('Classes')['Marks'].sum()

# %%
print(grouped11)
# Out:
# Classes
# 9      45
# 10    133
# 12     65
# Name: Marks, dtype: int64

# %%
grouping = employee_data.groupby('designation')['Salary'].mean()

# %%
print(grouping)
# Out:
# designation
# HR           26500.0
# Marketing    22000.0
# Sales        26000.0
# Name: Salary, dtype: float64

# %%
group = student1.groupby('adress').agg({
    'Marks':['min','max','mean']
})

# %%
print(group)
# Out:
#           Marks
#             min max  mean
# adress
# atrauliya    65  75  70.0
# lucknow      58  58  58.0
# madiyapar    45  45  45.0

# %%
customer = {
    'id' :[101,102,103],
    'name' :['roshan','vikash','prashant'],
    'marks' :[45,55,65] 
}

# %%
customers =pd.DataFrame({
    'id' :[101,102,104],
    'age' :[18,20,25],
    'class':[10,12,11]
})

# %%
print(customers)
# Out:
#     id  age  class
# 0  101   18     10
# 1  102   20     12
# 2  104   25     11

# %%
customer1 = pd.DataFrame(customer)

# %%
print(customer1)
# Out:
#     id      name  marks
# 0  101    roshan     45
# 1  102    vikash     55
# 2  103  prashant     65

# %%
join = pd.merge(customers,customer1, on='id' , how='inner')

# %%
print(join)
# Out:
#     id  age  class    name  marks
# 0  101   18     10  roshan     45
# 1  102   20     12  vikash     55

# %%
left_join = pd.merge(customers,customer1,on='id',how='left')

# %%
print(left_join)
# Out:
#     id  age  class    name  marks
# 0  101   18     10  roshan   45.0
# 1  102   20     12  vikash   55.0
# 2  104   25     11     NaN    NaN

# %%
right_join = pd.merge(customers,customer1,on='id',how='right')

# %%
print(right_join)
# Out:
#     id   age  class      name  marks
# 0  101  18.0   10.0    roshan     45
# 1  102  20.0   12.0    vikash     55
# 2  103   NaN    NaN  prashant     65

# %%
all_join = pd.merge(customers,customer1,on='id')

# %%
print(all_join)
# Out:
#     id  age  class    name  marks
# 0  101   18     10  roshan     45
# 1  102   20     12  vikash     55

# %%
custom =pd.DataFrame({
    'id' :[101,102,103],
    'name' :['roshan','vikash','prashant'],
    'marks' :[45,55,65] 
})

# %%
customs =pd.DataFrame({
    'id' :[101,102,104],
    'age' :[18,20,25],
    'class':[10,12,11]
})

# %%
alljoin = pd.merge(custom,customs,on='id',how='outer')

# %%
alljoin
# Out:
#     id      name  marks   age  class
# 0  101    roshan   45.0  18.0   10.0
# 1  102    vikash   55.0  20.0   12.0
# 2  103  prashant   65.0   NaN    NaN
# 3  104       NaN    NaN  25.0   11.0

# %%
sales = pd.DataFrame({
    'Date': ['2024-01-01', '2024-01-01', '2024-01-02', '2024-01-02'],
    'Product': ['A', 'B', 'A', 'B'],
    'Sales': [100, 150, 200, 130],
    'Region': ['East', 'West', 'East', 'West']
})

pivot = pd.pivot_table(sales, values='Sales', index='Product', columns='Region', aggfunc='sum', fill_value=0)
print("Pivot Table (Sales by Product and Region):\n", pivot)
# Out:
# Pivot Table (Sales by Product and Region):
#  Region   East  West
# Product
# A         300     0
# B           0   280

# %%
sales_data = pd.DataFrame({
    'id' :[101,102,103,104],
    'Name' :['Roshan','vijay','suresh','Ramesh'],
    'Product' :['mouse','keyboard','CPU','CPU'],
    'Quantity' :[5,6,4,3],
    'Rate' :[150,200,550,800],
})

# %%
sales_data
# Out:
#     id    Name   Product  Quantity  Rate
# 0  101  Roshan     mouse         5   150
# 1  102   vijay  keyboard         6   200
# 2  103  suresh       CPU         4   550
# 3  104  Ramesh       CPU         3   800

# %%
sales_data['total_amount'] = sales_data['Rate']*sales_data['Quantity']

# %%
sales_data
# Out:
#     id    Name   Product  Quantity  Rate  total_amount
# 0  101  Roshan     mouse         5   150           750
# 1  102   vijay  keyboard         6   200          1200
# 2  103  suresh       CPU         4   550          2200
# 3  104  Ramesh       CPU         3   800          2400

# %%
pivot = pd.pivot_table(
    sales_data,
    values='Quantity',
    index='Name',
    columns='Product',
    aggfunc='sum',
    margins='True' 
)

# %%
pivot
# Out:
# Product  CPU  keyboard  mouse  All
# Name
# Ramesh   3.0       NaN    NaN    3
# Roshan   NaN       NaN    5.0    5
# suresh   4.0       NaN    NaN    4
# vijay    NaN       6.0    NaN    6
# All      7.0       6.0    5.0   18

# %%
sales_data
# Out:
#     id    Name   Product  Quantity  Rate  total_amount
# 0  101  Roshan     mouse         5   150           750
# 1  102   vijay  keyboard         6   200          1200
# 2  103  suresh       CPU         4   550          2200
# 3  104  Ramesh       CPU         3   800          2400

# %%
cross = pd.crosstab(
  sales_data['Product'],
  sales_data['Name']
)

# %%
cross
# Out:
# Name      Ramesh  Roshan  suresh  vijay
# Product
# CPU            1       0       1      0
# keyboard       0       0       0      1
# mouse          0       1       0      0

# %%
sales_data
# Out:
#     id    Name   Product  Quantity  Rate  total_amount
# 0  101  Roshan     mouse         5   150           750
# 1  102   vijay  keyboard         6   200          1200
# 2  103  suresh       CPU         4   550          2200
# 3  104  Ramesh       CPU         3   800          2400

# %%
sales_data.plot(
    kind='bar',
    x='Name',
    y='total_amount',    
)

sales_data.plot(
    kind='line',
    x='Name',
    y='Quantity',    
)

sales_data.plot(
    kind='pie',
    x='Product',
    y='total_amount',
    
)
# Out:
# <Axes: >
