# %% [markdown]
# ## imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print("="*60)
print("1.series(1D labeled array)")
print("="*60)
# Out:
# ============================================================
# 1.series(1D labeled array)
# ============================================================

# %%
s1 = pd.Series([10,20,30,40], index = ["a","b","c","d"])
print(f"list of series:\n",s1)
# Out:
# list of series:
#  a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s21 = pd.Series(['Roshan','Umesh','Mukesh','Mankram'],index=[1,2,3,4])
print(s21)
# Out:
# 1     Roshan
# 2      Umesh
# 3     Mukesh
# 4    Mankram
# dtype: str

# %%
s2 = pd.Series({'math':85, 'english':98, 'science':45, 'hindi':65})
print(f"series of dictionary\n",s2)
# Out:
# series of dictionary
#  math       85
# english    98
# science    45
# hindi      65
# dtype: int64

# %%
data = {
    'name':['Roshan','Vikash','Prashant','Vijay'],
    'age':[22,23,19,20],
    'city':['Atrauliya','Deoria','Azamgarh','Madiyapar'],
    'score':[34,43,56,43,]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        name  age       city  score
# 0    Roshan   22  Atrauliya     34
# 1    Vikash   23     Deoria     43
# 2  Prashant   19   Azamgarh     56
# 3     Vijay   20  Madiyapar     43

# %%
df2 = pd.DataFrame([(2,'x'), (3,'y')], columns=['id', 'names'])
print(df2)
# Out:
#    id names
# 0   2     x
# 1   3     y

# %%
df3 = pd.DataFrame([(2,'Roshan'), (3,'Pradeep')], columns=['id','Names'])
print(df3)
# Out:
#    id    Names
# 0   2   Roshan
# 1   3  Pradeep

# %%
df.to_csv('student.csv', index=False)
print()

# %%
df.to_excel('student.xlsx', index=False)
print()

# %%
import sys
!"{sys.executable}" -m pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\dell\appdata\local\programs\python\python314\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\dell\appdata\local\programs\python\python314\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
