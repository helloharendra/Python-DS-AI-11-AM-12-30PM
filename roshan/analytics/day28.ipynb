# %%
print('Hello world')
# Out:
# Hello world

# %%
! pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    if not ret:
        break 
    cv2.flip(frame,1)
    cv2.imshow("Mirror Face Detection",frame)


    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_defauly.xml'
)

cap = cv2.VideaCapture(0)
while True:
    ret, frame = cap.read()

    if not ret:
        break 

    frame = cv2.flip(frame, 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 6
#       2 face_cascade = cv2.CascadeClassifier(
#       3     cv2.data.haarcascades + 'haarcascade_frontalface_defauly.xml'
#       4 )
#       5
# ----> 6 cap = cv2.VideaCapture(0)
#       7 while True:
#       8     ret, frame = cap.read()
#       9
#
# AttributeError: module 'cv2' has no attribute 'VideaCapture'

# %%
def factorial(n):
    if n==1:
        return 1
    else:
        return n*factorial(n-1)

# %%
print(factorial(5))
# Out:
# 120

# %%
import pandas as pd

# %%
l1 = [1,2,3,4]

# %%
l1.pop(3)
# Out:
# 4

# %%
print(l1)
# Out:
# [1, 2, 3]

# %%
import pandas as pd

# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
series1 = pd.Series(
    [10,20,30,40,50],
    index=['a','b','c','d','e']
)

# %%
series1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
data = pd.DataFrame(series1)

# %%
data
# Out:
#     0
# a  10
# b  20
# c  30
# d  40
# e  50

# %%
series2 = pd.Series({
    'Name':['Ram','Shyam','Mohan'],
    'Age':[50,40,30]
})

# %%
series2
# Out:
# Name    [Ram, Shyam, Mohan]
# Age            [50, 40, 30]
# dtype: object

# %%
df = pd.read_csv('student.csv')
print(df.head(2))
print(df.tail(2))
# Out:
#      name  age       city  score
# 0  Roshan   22  Atrauliya     34
# 1  Vikash   23     Deoria     43
#        name  age       city  score
# 2  Prashant   19   Azamgarh     56
# 3     Vijay   20  Madiyapar     43

# %%
df
# Out:
#        name  age       city  score
# 0    Roshan   22  Atrauliya     34
# 1    Vikash   23     Deoria     43
# 2  Prashant   19   Azamgarh     56
# 3     Vijay   20  Madiyapar     43

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      str
#  1   age     4 non-null      int64
#  2   city    4 non-null      str
#  3   score   4 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 260.0 bytes
# None
#              age      score
# count   4.000000   4.000000
# mean   21.000000  44.000000
# std     1.825742   9.055385
# min    19.000000  34.000000
# 25%    19.750000  40.750000
# 50%    21.000000  43.000000
# 75%    22.250000  46.250000
# max    23.000000  56.000000

# %%
print(df.shape)
print(df.columns)
print(df.index)
# Out:
# (4, 4)
# Index(['name', 'age', 'city', 'score'], dtype='str')
# RangeIndex(start=0, stop=4, step=1)

# %%
import pandas as pd

# %%
data1 = {
    'Name':['Roshan','Vikash','Akash','Rahul'],
    'Age':[20,25,30,22],
    'Classes':[10,12,9,10],
    'Marks':[25,65,45,36]
}

# %%
df1 =pd.DataFrame(data1)

# %%
df1.loc[1,"Name"]
# Out:
# 'Vikash'

# %%
import numpy as np
df1
# Out:
#      Name  Age  Classes  Marks
# 0  Roshan   20       10     25
# 1  Vikash   25       12     65
# 2   Akash   30        9     45
# 3   Rahul   22       10     36

# %%
df1.iloc[1,0]
# Out:
# 'Vikash'

# %%
df1.loc[0,'Age']
# Out:
# np.int64(20)

# %%
import pandas as pd

# %%
data2 = {
    'Name':['Roshan','Vikash','Akash','Rahul'],
    'Age':[np.nan,25,30,22],
    'Classes':[10,np.nan,9,10],
    'Marks':[25,65,np.nan,36]
}

# %%
df2 = pd.DataFrame(data2)

# %%
df2
# Out:
#      Name   Age  Classes  Marks
# 0  Roshan   NaN     10.0   25.0
# 1  Vikash  25.0      NaN   65.0
# 2   Akash  30.0      9.0    NaN
# 3   Rahul  22.0     10.0   36.0

# %%
filling = df2.fillna(0)

# %%
filling
# Out:
#      Name   Age  Classes  Marks
# 0  Roshan   0.0     10.0   25.0
# 1  Vikash  25.0      0.0   65.0
# 2   Akash  30.0      9.0    0.0
# 3   Rahul  22.0     10.0   36.0

# %%
null = df2.isnull()

# %%
null
# Out:
#     Name    Age  Classes  Marks
# 0  False   True    False  False
# 1  False  False     True  False
# 2  False  False    False   True
# 3  False  False    False  False

# %%
df2.isnull().any()
# Out:
# Name       False
# Age         True
# Classes     True
# Marks       True
# dtype: bool

# %%
filling
# Out:
#      Name   Age  Classes  Marks
# 0  Roshan   0.0     10.0   25.0
# 1  Vikash  25.0      0.0   65.0
# 2   Akash  30.0      9.0    0.0
# 3   Rahul  22.0     10.0   36.0

# %%
df2['Age']=df2['Age'].fillna(df2['Age'].mean())

# %%
df2
# Out:
#      Name        Age  Classes  Marks
# 0  Roshan  25.666667     10.0   25.0
# 1  Vikash  25.000000      NaN   65.0
# 2   Akash  30.000000      9.0    NaN
# 3   Rahul  22.000000     10.0   36.0

# %%
op = {
    'Name':['Roshan','Vikash','Akash','Rahul'],
    'Age':[20,25,30,22],
    'Classes':[10,12,9,10],
    'Marks':[25,65,45,36]
}

# %%
emp = pd.DataFrame(op)

# %%
emp
# Out:
#      Name  Age  Classes  Marks
# 0  Roshan   20       10     25
# 1  Vikash   25       12     65
# 2   Akash   30        9     45
# 3   Rahul   22       10     36

# %%
emp['Bonus']=emp['Marks']*2
print(emp)
# Out:
#      Name  Age  Classes  Marks  Bonus
# 0  Roshan   20       10     25     50
# 1  Vikash   25       12     65    130
# 2   Akash   30        9     45     90
# 3   Rahul   22       10     36     72

# %%
emp['Age_Next_year']=emp['Age']+1

# %%
emp
# Out:
#      Name  Age  Classes  Marks  Bonus  Age_Next_year
# 0  Roshan   20       10     25     50             21
# 1  Vikash   25       12     65    130             26
# 2   Akash   30        9     45     90             31
# 3   Rahul   22       10     36     72             23

# %%
emp['Age'],emp['Age_Next_year']
# Out:
# (0    20
#  1    25
#  2    30
#  3    22
#  Name: Age, dtype: int64,
#  0    21
#  1    26
#  2    31
#  3    23
#  Name: Age_Next_year, dtype: int64)

# %%
emp[['Age', 'Age_Next_year']]
# Out:
#    Age  Age_Next_year
# 0   20             21
# 1   25             26
# 2   30             31
# 3   22             23
