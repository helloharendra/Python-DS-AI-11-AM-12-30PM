# %%
list3 =["apple","mango","banana"]
for i in range(len(list3)):
    print(list3[i])
# Out:
# apple
# mango
# banana

# %%
list3.insert(2,"lichi")

# %%
print(list3)
# Out:
# ['apple', 'mango', 'lichi', 'banana']

# %%
list3.remove("lichi")

# %%
print(list3)
# Out:
# ['apple', 'mango', 'banana']

# %%
list3.append("lichi")

# %%
print(list3)
# Out:
# ['apple', 'mango', 'banana', 'lichi']

# %%
list3.pop(1)
# Out:
# 'mango'

# %%
print(list3)
# Out:
# ['apple', 'banana', 'lichi']

# %%
def factorialnumber(n):
    if n==1 :
        return 1
    else:
        return n *factorialnumber(n-1)

# %%
factorialnumber(5)
# Out:
# 120

# %%
def fabnocci(n):
    if n==0:
        return 0
    if n==1:
        return 1
    else:
        return fabnocci(n-1)+ fabnocci(n-2)

# %%
fabnocci(5)
# Out:
# 5

# %% [markdown]
# - remember this its very important

# %%
def num(n):
    if n==0:
        return
    num(n-1)
    print(n)

# %%
print(num(5))
# Out:
# 1
# 2
# 3
# 4
# 5
# None

# %%
item=["mango","apple","banana"]
for i in item:
    print(i)
# Out:
# mango
# apple
# banana

# %%
for i in range(len(item)-1,-1,-1):
    print(item[i])
# Out:
# lichi
# banana
# apple
# mango

# %%
item.append("lichi")

# %%
for i in range(len(item)):
    if item[i]=="lichi":
        print("found at",i)
# Out:
# found at 3
